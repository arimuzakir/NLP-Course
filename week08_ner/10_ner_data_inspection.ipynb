# %% [markdown]
# # NER Data Inspection

# %%
from pathlib import Path
root=Path.cwd().parents[0]; path=root/'data'/'ner'/'kalimat_POS_NE_train.txt'
for line in path.read_text(encoding='utf-8').splitlines()[:40]: print(line)

# %% [markdown]
# ## Latihan
#
# 1. Identifikasi token, POS, dan label.
# 2. Jelaskan B-, I-, O.
# 3. Hitung frekuensi label.
# 4. Jelaskan satu entity boundary.
# 5. Tambahkan fitur pada kode CRF lama dan jelaskan alasan.
