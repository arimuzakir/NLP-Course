# %% [markdown]
# # Sintaksis: POS dan Parsing

# %%
sentences=['Mahasiswa membaca buku NLP.','Dosen membahas model bahasa.','Sistem mendeteksi komentar beracun.','Peneliti mengevaluasi model dengan data baru.','Model yang dilatih kemarin memberikan hasil baik.']
for s in sentences: print(s)

# %% [markdown]
# ## Latihan manual
#
# Untuk setiap kalimat identifikasi head/dependent dan struktur S/P/O/K atau struktur yang sesuai. Catat bagian ambigu.
