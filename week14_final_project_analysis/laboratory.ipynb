# %% [markdown]
# # Final Project IV - Error Analysis

# %% [markdown]
# Ambil minimal 20 error atau seluruh error jika kurang dari 20.

# %%
errors=pd.DataFrame(columns=['id','input','gold','pred','error_type','cause','action']); errors

# %% [markdown]
# ## Improvement experiment
# Pilih satu kategori error dan lakukan satu eksperimen perbaikan.

# %%
print('Dokumentasikan before/after di sini.')
