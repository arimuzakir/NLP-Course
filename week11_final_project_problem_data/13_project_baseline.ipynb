# %% [markdown]
# # Final Project - Baseline

# %% [markdown]
# ## Checklist
# - [ ] Problem statement
# - [ ] Research question
# - [ ] Dataset
# - [ ] Label distribution
# - [ ] Train/validation/test split
# - [ ] Baseline representation
# - [ ] Baseline model
# - [ ] Evaluation metric

# %%
print('Isi notebook dengan dataset dan baseline project Anda.')
