# %% [markdown]
# # Final Project I - Problem and Data

# %% [markdown]
# ## Project Canvas
# Isi sebelum coding: problem, stakeholder, task, research questions, dataset, labels, primary metric, baseline.

# %%
import pandas as pd
canvas=pd.DataFrame({'item':['Problem','Stakeholder','Task','RQ1','RQ2','Dataset','Labels','Primary metric','Baseline'],'answer':['']*9}); canvas

# %% [markdown]
# ## Data card
# Dokumentasikan source, collection, license, distribution, duplicates, missing values, annotation process, ethical risks.

# %%
data_card=pd.DataFrame(columns=['field','description','value'])
data_card

# %% [markdown]
# ## Deliverable
# Proposal 2-4 halaman + data card + EDA notebook.
