# %% [markdown]
# # Final Project VI - Reproducible Release

# %%
check=pd.DataFrame({'artifact':['README','requirements','data instructions','training code','evaluation code','results','error analysis','report','slides'],'done':[False]*9}); check

# %% [markdown]
# ## Final rule
# Orang lain harus dapat memahami dan menjalankan project hanya dari README dan repository.
