# %% [markdown]
# # Final Project III - Experiments

# %% [markdown]
# Minimal dua model + satu ablation/sensitivity experiment.

# %%
experiments=pd.DataFrame(columns=['id','change','hypothesis','metric','result','interpretation']); experiments

# %% [markdown]
# ## Rule
# Ubah satu faktor pada satu waktu dan catat parameter.

# %%
print('Tambahkan eksperimen Anda.')
