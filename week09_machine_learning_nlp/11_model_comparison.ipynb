# %% [markdown]
# # Fair Model Comparison

# %%
print('Gunakan BBC dataset lokal dari minggu 9. Pertahankan split dan preprocessing yang sama untuk perbandingan model.')

# %% [markdown]
# ## Prinsip eksperimen
#
# Ubah satu faktor pada satu waktu. Catat parameter, metrik, dan interpretasi.
