# %% [markdown]
# # Final Project II - Baseline

# %% [markdown]
# Baseline harus sederhana, reproducible, dan menjadi pembanding untuk model berikutnya.

# %%
experiment_log=pd.DataFrame(columns=['exp_id','representation','model','parameters','metric','score','notes']); experiment_log

# %% [markdown]
# ## Checklist
# - fixed split
# - random seed
# - preprocessing
# - baseline model
# - metric
# - saved predictions

# %%
print('Implementasikan baseline project Anda di sini.')
