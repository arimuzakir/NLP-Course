# %% [markdown]
# # Final Project - Experiment Log

# %% [markdown]
# | Experiment | Representation | Model | Parameter | Metric | Result | Notes |
# |---|---|---|---|---|---|---|
# | E1 | baseline | model 1 | - | macro F1 | - | - |
# | E2 | baseline | model 2 | - | macro F1 | - | - |
# | E3 | advanced | model 2 | - | macro F1 | - | - |

# %% [markdown]
# ## Error Analysis
#
# Catat input, gold label, prediction, kemungkinan penyebab, dan jenis perbaikannya.
