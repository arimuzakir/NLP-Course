# %% [markdown]
# # Minggu 2 - Text Normalization dan Preprocessing
#
# **Guided laboratory.** Jalankan cell secara berurutan.

# %% [markdown]
# ## 1. Learning objectives
#
# - Cleaning harus disesuaikan dengan task.
# - Case folding, whitespace, punctuation, URL, mention, emoji, stopword, stemming/lemmatization memiliki trade-off.
# - Preprocessing yang terlalu agresif dapat menghilangkan signal.

# %%
from pathlib import Path
import re, numpy as np, pandas as pd
ROOT=Path.cwd().resolve()
while ROOT.name!='NLP-S2-BinaDarma-Course' and ROOT.parent!=ROOT:
    ROOT=ROOT.parent
print('Root:',ROOT)

# %% [markdown]
# ## 2. Warm-up
#
# Sebelum coding, tulis satu hipotesis tentang apa yang akan terjadi pada data.

# %%
hypothesis='Tuliskan hipotesis Anda di sini.'
print(hypothesis)

# %% [markdown]
# ## 3. Guided exercise
#
# Gunakan notebook ini bersama `materi.md`. Tambahkan eksperimen Anda di bawah cell ini.

# %%
experiment_notes=pd.DataFrame({'item':['Baseline','Experiment 1','Experiment 2','Interpretation'],'notes':['','','','']})
experiment_notes

# %% [markdown]
# ## 4. Challenge
#
# Ubah minimal satu komponen metode. Catat sebelum/sesudah dan jelaskan penyebab perubahan.

# %%
print('Tambahkan kode challenge Anda di cell ini.')

# %% [markdown]
# ## 5. Reflection
#
# Jelaskan apa yang dipelajari, apa yang gagal, dan apa eksperimen berikutnya.
