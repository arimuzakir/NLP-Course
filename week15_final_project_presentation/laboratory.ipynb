# %% [markdown]
# # Final Project V - Presentation

# %% [markdown]
# Struktur 10-15 menit: Problem → Research Question → Data → Method → Baseline → Results → Error Analysis → Limitations → Conclusion.

# %%
slides=pd.DataFrame({'section':['Problem','RQ','Data','Method','Baseline','Results','Errors','Limitations','Conclusion'],'status':['todo']*9}); slides

# %% [markdown]
# ## Q&A preparation
# Siapkan 5 pertanyaan sulit yang mungkin ditanyakan reviewer/dosen dan jawaban berbasis evidence.
